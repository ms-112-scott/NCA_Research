# %%
import torch
import wandb
import numpy as np
from src.models.base_texture_nca import BaseTextureNCA
from src.loss.vgg_loss import VGGLoss
from src.trainer.nca_trainer import NCATrainer
from src.help.utils import set_seed, load_target_image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# 1. 設定預設 Config
default_config = {
    'project_name': 'base_texture_nca',
    'chn': 12,              
    'hidden_n': 96,         
    'batch_size': 8,        
    'step_min': 32,         
    'step_max': 96,         
    'pool_reset_freq': 8,
    'pool_size': 1024,      # 新增: Pool 大小
    'lr': 2e-3,             # 新增: 學習率
    'seed': 42,             # 新增: 種子
    'target_img_path': 'data/texture.jpg', # 新增: 目標圖片路徑
    'img_size': 128,        # 新增: 圖片大小
    'use_gradient_checkpoint': False
}

# %%
def model_pipeline(hyperparams):
    with wandb.init(project="base_texture_nca", config=hyperparams):
        config = wandb.config
        model, optim, datapool, loss_fn , 其他必需的東西 = setup_case(config) # 初始化所有東西
        
        train(model, optim, datapool, loss_fn , 其他必需的東西, config)
        
        test(model, config)

    return model

def setup_case(config):
    # 建立模型
    model = BaseTexureNCA(config).to(device)
    
    # 建立優化器
    optim = torch.optim.Adam(model.parameters(), lr=1e-3)
    
    # 建立資料池
    datapool = TextureDataPool(config['batch_size'])
    
    # 定義損失函數
    loss_fn = vgg_loss()
    
    # 其他必需的東西
    其他必需的東西 = {}
    
    return model, optim, datapool, loss_fn , 其他必需的東西

# %%
model_pipeline(config)
# Out:
# Output shape: torch.Size([1, 16, 64, 64])
